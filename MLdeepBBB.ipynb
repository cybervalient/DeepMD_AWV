# %% [markdown]
# <a href="https://colab.research.google.com/github/cybervalient/DeepMD_AWV/blob/main/MLdeepBBB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h2o
# Out:
# ...
#      |████████████████████████████████| 177.0 MB 21 kB/s
# ...
#   Created wheel for h2o: filename=h2o-3.36.1.1-py2.py3-none-any.whl size=177068062 sha256=e6c1e79fdfe63e66d6ce1b9f7c33a210de94f0da3018ae19d785a9b9b394f1fa
#   Stored in directory: /root/.cache/pip/wheels/a6/d9/ab/5442447c7e2ccf07f66aa8b79f3877ce5382f0b95e6c0c797b
# Successfully built h2o
# ...

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init(max_mem_size='16G')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.15" 2022-04-19; OpenJDK Runtime Environment (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1); OpenJDK 64-Bit Server VM (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmprls8atk6
#   JVM stdout: /tmp/tmprls8atk6/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmprls8atk6/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.1
# H2O_cluster_version_age:    26 days
# ...

# %%
from google.colab import files  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f341b14-fcc8-43bf-9c89-28610f9124d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f341b14-fcc8-43bf-9c89-28610f9124d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AO-classics-largeBBB.csv to AO-classics-largeBBB.csv

# %%
import io 
df = h2o.import_file('AO-classics-largeBBB.csv')
df.head()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# ...

# %%
print(f'Size of training set: {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# Size of training set: 596 rows and 1668 columns

# %%
splits = df.split_frame(ratios=[0.8],seed=1)
train = splits[0]
test = splits[1]

# %%
y = "logBB" 
x = df.columns 
x.remove(y) 
x.remove("name")

# %%
aml = H2OAutoML(max_runtime_secs=120, seed=1)
aml.train(x=x,y=y, training_frame=train)

lb = aml.leaderboard
lb.head()
# Out:
# AutoML progress: |
# 20:08:58.955: _train param, Dropping bad and constant columns: [K-NE-BD-WH-HL, 1GI-NE(P3)-P-WH-HL, 1GI-NE(N2)-L-WH-HD, MI-NE(K)-L-WH-HL, MI-NE(P3)-BD-WH-HL, 1GI-NE(P3)-KU-WH-HL, MI-NE(N2)-BD-WH-HD, 1GI-NE(P3)-DC4-WH-HL, K-NE-BD-WH-HD, 1GI-NE(N2)-KU-WH-HL, 1GI-NE(K)-DC3-WH-HL, 1GI-NE(N2)-DC3-WH-HL, MI-NE(K)-DC3-WH-HL, MI-NE(P3)-BD-WH-HD, 1GI-NE(K)-P-WH-HL, MI-NE(N2)-BD-WH-HL, 1GI-NE(K)-DC2-WH-HL, 1GI-NE(P3)-L-WH-HD, 1GI-NE(K)-L-WH-HD, 1GI-NE(P3)-DC3-WH-HL, 1GI-NE(N2)-P-WH-HL, 1GI-NE(N2)-BD-WH-HL, 1GI-NE(K)-KU-WH-HL, 1GI-NE(P3)-BD-WH-HL, MI-NE(K)-BD-WH-HL, 1GI-NE(N2)-DC2-WH-HL, MI-NE(K)-BD-WH-HD, 1GI-NE(K)-BD-WH-HL, 1GI-NE(N2)-DC4-WH-HL, MI-NE(K)-DC4-WH-HL, SI-NE-BD-WH-HD, 1GI-NE(P3)-L-WH-HL, 1GI-NE(K)-L-WH-HL, MI-NE(K)-L-WH-RA, MI-NE(K)-BD-WH-RA, MI-NE(K)-KU-WH-HD, MI-NE(K)-P-WH-HL, 1GI-NE(N2)-L-WH-HL, MI-NE(K)-DC2-WH-HL, 1GI-NE(K)-DC4-WH-HL, MI-NE(K)-KU-WH-HL, 1GI-NE(P3)-DC2-WH-HL, SI-NE-BD-WH-HL]
#
# ██
# ...

# %%
# Get model ids for all models in the AutoML Leaderboard
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
# Get the "All Models" Stacked Ensemble model
se = h2o.get_model([mid for mid in model_ids if "StackedEnsemble_AllModels" in mid][0])
# Get the Stacked Ensemble metalearner model
metalearner = h2o.get_model(se.metalearner()['name'])
# Out:
# /usr/local/lib/python3.7/dist-packages/h2o/estimators/stackedensemble.py:929: H2ODeprecationWarning: The usage of stacked_ensemble.metalearner()['name'] will be deprecated. Metalearner now returns the metalearner object. If you need to get the 'name' please use stacked_ensemble.metalearner().model_id
#   H2ODeprecationWarning

# %%
metalearner
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  metalearner_AUTO_StackedEnsemble_AllModels_2_AutoML_1_20220509_200856
#
#
# GLM Model: summary
#        family      link                                regularization  \
# 0    gaussian  identity  Elastic Net (alpha = 0.5, lambda = 0.02768 )
#
#                                                            lambda_search  \
# 0  nlambda = 100, lambda.max = 0.3258, lambda.min = 0.02768, lambda.1...
#
#    number_of_predictors_total number_of_active_predictors  \
# 0                          12                           6
#
#    number_of_iterations  \
# 0                    54
#
#                                                           training_frame
# 0  levelone_training_StackedEnsemble_AllModels_2_AutoML_1_20220509_20...
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 0.3442324982281932
# RMSE: 0.5867133015606457
# MAE: 0.4634004064736272
# RMSLE: NaN
# ...

# %%
# %matplotlib inline
metalearner.std_coef_plot()

# %%
pred = aml.predict(test)
pred.head()
# Out:
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">   predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">-1.309    </td></tr>
# <tr><td style="text-align: right;">-0.615986 </td></tr>
# <tr><td style="text-align: right;">-1.14705  </td></tr>
# <tr><td style="text-align: right;">-0.0825453</td></tr>
# <tr><td style="text-align: right;">-0.441365 </td></tr>
# <tr><td style="text-align: right;">-0.687472 </td></tr>
# <tr><td style="text-align: right;">-0.822282 </td></tr>
# <tr><td style="text-align: right;">-0.14293  </td></tr>
# <tr><td style="text-align: right;">-0.253641 </td></tr>
# <tr><td style="text-align: right;">-0.440701 </td></tr>
# </tbody>
# </table>
