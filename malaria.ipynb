# %% [markdown]
# <a href="https://colab.research.google.com/github/cybervalient/DeepMD_AWV/blob/main/malaria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install h2o
# Out:
# ...
#      |████████████████████████████████| 176.2 MB 1.6 kB/s
# ...
#   Created wheel for h2o: filename=h2o-3.36.0.4-py2.py3-none-any.whl size=176245474 sha256=e58b535f50a2527cf5d6d925df06787a99afc76e15a7ea54f6e3b93ec987a3d5
#   Stored in directory: /root/.cache/pip/wheels/66/7c/3b/6558f625a9415a96f7f650d33f1def07b6e30b0c871e8407a1
# Successfully built h2o
# ...

# %%
# !pip install pandas

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init(max_mem_size='16G')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.14" 2022-01-18; OpenJDK Runtime Environment (build 11.0.14+9-Ubuntu-0ubuntu2.18.04); OpenJDK 64-Bit Server VM (build 11.0.14+9-Ubuntu-0ubuntu2.18.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpuz7p51s1
#   JVM stdout: /tmp/tmpuz7p51s1/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpuz7p51s1/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.0.4
# H2O_cluster_version_age:    4 days
# ...

# %%
from google.colab import files  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e2364f39-f826-42ec-9be5-e968092bb4db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2364f39-f826-42ec-9be5-e968092bb4db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving malaria_AC.csv to malaria_AC.csv

# %%
import pandas as pd 
import io 
  
df = h2o.import_file('malaria_AC.csv')
df.head()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# ...

# %%
print(f'Size of training set: {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# Size of training set: 400 rows and 202 columns

# %%
splits = df.split_frame(ratios=[0.8],seed=1)
train = splits[0]
test = splits[1]

# %%
y = "logEC50" 
x = df.columns 
x.remove(y) 
x.remove("name")

# %%
aml = H2OAutoML(max_runtime_secs=120, seed=1)
aml.train(x=x,y=y, training_frame=train)

lb = aml.leaderboard
lb.head()
# Out:
# AutoML progress: |██████████████████
# 08:58:38.622: GBM_1_AutoML_1_20220404_85802 [GBM def_5] failed: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: GBM_1_AutoML_1_20220404_85802.  Details: ERRR on field: _min_rows: The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 168.0.
# ERRR on field: _min_rows: The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 168.0.
# ERRR on field: _min_rows: The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 168.0.
# ERRR on field: _min_rows: The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 168.0.
# ERRR on field: _min_rows: The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 168.0.
#
#
# ...

# %%
# Get model ids for all models in the AutoML Leaderboard
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
# Get the "All Models" Stacked Ensemble model
se = h2o.get_model([mid for mid in model_ids if "StackedEnsemble_AllModels" in mid][0])
# Get the Stacked Ensemble metalearner model
metalearner = h2o.get_model(se.metalearner()['name'])
# Out:
# /usr/local/lib/python3.7/dist-packages/h2o/estimators/stackedensemble.py:929: H2ODeprecationWarning: The usage of stacked_ensemble.metalearner()['name'] will be deprecated. Metalearner now returns the metalearner object. If you need to get the 'name' please use stacked_ensemble.metalearner().model_id
#   H2ODeprecationWarning

# %%
# %matplotlib inline
metalearner.std_coef_plot()

# %%
pred = aml.predict(test)
pred.head()
# Out:
# glm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 1.08411 </td></tr>
# <tr><td style="text-align: right;"> 1.31821 </td></tr>
# <tr><td style="text-align: right;"> 1.12173 </td></tr>
# <tr><td style="text-align: right;"> 1.46901 </td></tr>
# <tr><td style="text-align: right;"> 0.961591</td></tr>
# <tr><td style="text-align: right;"> 1.164   </td></tr>
# <tr><td style="text-align: right;"> 1.47513 </td></tr>
# <tr><td style="text-align: right;"> 1.00697 </td></tr>
# <tr><td style="text-align: right;"> 1.3714  </td></tr>
# <tr><td style="text-align: right;"> 1.20776 </td></tr>
# </tbody>
# </table>

# %%
h2o.save_model(aml.leader, path="./IB_model_bin")
# Out:
# ---------------------------------------------------------------------------
# H2OResponseError                          Traceback (most recent call last)
# <ipython-input-21-035afee3f99d> in <module>()
# ----> 1 h2o.save_model(aml.leader, path="./IB_model_bin")
#
# /usr/local/lib/python3.7/dist-packages/h2o/h2o.py in save_model(model, path, force, export_cross_validation_predictions, filename)
#    1454     path = os.path.join(os.getcwd() if path == "" else path, filename)
#    1455     data = {"dir": path, "force": force, "export_cross_validation_predictions": export_cross_validation_predictions}
# -> 1456     return api("GET /99/Models.bin/%s" % model.model_id, data=data)["dir"]
#    1457
#    1458
#
# /usr/local/lib/python3.7/dist-packages/h2o/h2o.py in api(endpoint, data, json, filename, save_to)
#     122     # type checks are performed in H2OConnection class
#     123     _check_connection()
# ...

# %%
# !pip install tensorflow

# %%
# !pip install keras
